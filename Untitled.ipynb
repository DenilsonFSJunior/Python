# %%
Aluno: Denilson Ferreira Dos Santos Júnior

# %%
Trabalho da Disciplina: APLIC De CLOUD, IOT E IDUSTRIA 4.0 EM PYTHON.
PROFESSOR: Fábio Oliveira

# %%
import pandas as pd
# Leitura do arquivo CSV
df_seg = pd.read_csv("C:\\Users\\denil\\Trabalho_Fabio\\produtividade_policial.csv\\produtividade_policial.csv")

# Exibe as primeiras linhas do DataFrame
#print(data.shape)
# Exibindo os nomes das colunas
#data.columns
#data.head()

# %%
# Solicita ao usuário o bairro escolhido
print(df_seg['regiao_ssp'].unique())
regiao_ssp =str(input("Digite o Bairro escolhido: "))
bairro = df_seg[df_seg['regiao_ssp'] == regiao_ssp]

# Solicita ao usuario o ano escolhido
print(df_seg['ano'].unique())
ano = input("Digite o ano pesquisado")
ano_pesquisado = df_seg[df_seg['ano'] == ano]

# Filtra os dados para encontrar todos as ocorrencias do bairro
regiao_ssp_dados = df_seg[df_seg['regiao_ssp'] == regiao_ssp]

# Verifica se o bairro foi encontrada e imprime os dados
if not regiao_ssp_dados.empty:
    display(regiao_ssp_dados)
else:
       print("Nenhum bairro encontrado para a pesquisa fornecida.")
# Out:
# ['Presidente Prudente' 'Sorocaba' 'Ribeirão Preto'
#  'Grande São Paulo (exclui a Capital)' 'Bauru' 'São José do Rio Preto'
#  'Piracicaba' 'São José dos Campos' 'Campinas' 'Araçatuba' 'Santos'
#  'Capital']
# Digite o Bairro escolhido:  Campinas
# [2002 2003 2005 2009 2008 2004 2007 2006 2010 2011 2013 2012 2017 2014
#  2021 2018 2016 2019 2015 2020]
# Digite o ano pesquisado 2020
#          ano  mes  id_municipio regiao_ssp  \
# 348     2002    1       3556701   Campinas
# 349     2002    2       3556701   Campinas
# 350     2002    3       3556701   Campinas
# 351     2002    4       3556701   Campinas
# 352     2002    5       3556701   Campinas
# ...      ...  ...           ...        ...
# 150247  2020    8       3500501   Campinas
# 150248  2020    9       3500501   Campinas
# 150249  2020   10       3500501   Campinas
# 150250  2020   11       3500501   Campinas
# 150251  2020   12       3500501   Campinas
#
#         ocorrencias_de_porte_de_entorpecentes  \
# ...
